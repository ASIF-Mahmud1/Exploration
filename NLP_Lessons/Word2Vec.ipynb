# %% [markdown]
# <a href="https://colab.research.google.com/github/ASIF-Mahmud1/Exploration/blob/text-classifier/NLP_Lessons/Word2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Upload reviews_data.txt.gz file for Desktop

# %% [markdown]
# # Getting started with Word2Vec in Gensim and making it work!
#
# The idea behind Word2Vec is pretty simple. We are making and assumption that you can tell the meaning of a word by the company it keeps. This is analogous to the saying *show me your friends, and I'll tell who you are*. So if you have two words that have very similar neighbors (i.e. the usage context is about the same), then these words are probably quite similar in meaning or are at least highly related. For example, the words `shocked`,`appalled` and `astonished` are typically used in a similar context.
#
# In this tutorial, you will learn how to use the Gensim implementation of Word2Vec and actually get it to work! I have heard a lot of complaints about poor performance etc, but its really a combination of two things, (1) your input data and (2) your parameter settings. Note that the training algorithms in this package were ported from the [original Word2Vec implementation by Google](https://arxiv.org/pdf/1301.3781.pdf) and extended with additional functionality.

# %% [markdown]
# ### Imports and logging
#
# First, we start with our imports and get logging established:

# %%
# imports needed and set up logging
import gzip
import gensim 
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ### Dataset
# Next, is our dataset. The secret to getting Word2Vec really working for you is to have lots and lots of text data. In this case I am going to use data from the [OpinRank](http://kavita-ganesan.com/entity-ranking-data/) dataset. This dataset has full user reviews of cars and hotels. I have specifically concatenated all of the hotel reviews into one big file which is about 97MB compressed and 229MB uncompressed. We will use the compressed file for this tutorial. Each line in this file represents a hotel review. You can download the OpinRank Word2Vec dataset here.
#
# To avoid confusion, while gensim’s word2vec tutorial says that you need to pass it a sequence of sentences as its input, you can always pass it a whole review as a sentence (i.e. a much larger size of text), and it should not make much of a difference.
#
# Now, let's take a closer look at this data below by printing the first line. You can see that this is a pretty hefty review.

# %%
data_file="reviews_data.txt.gz"

with gzip.open ('reviews_data.txt.gz', 'rb') as f:
    for i,line in enumerate (f):
        print(line)
        break
# Out:
# b"Oct 12 2009 \tNice trendy hotel location not too bad.\tI stayed in this hotel for one night. As this is a fairly new place some of the taxi drivers did not know where it was and/or did not want to drive there. Once I have eventually arrived at the hotel, I was very pleasantly surprised with the decor of the lobby/ground floor area. It was very stylish and modern. I found the reception's staff geeting me with 'Aloha' a bit out of place, but I guess they are briefed to say that to keep up the coroporate image.As I have a Starwood Preferred Guest member, I was given a small gift upon-check in. It was only a couple of fridge magnets in a gift box, but nevertheless a nice gesture.My room was nice and roomy, there are tea and coffee facilities in each room and you get two complimentary bottles of water plus some toiletries by 'bliss'.The location is not great. It is at the last metro stop and you then need to take a taxi, but if you are not planning on going to see the historic sites in Beijing, then you will be ok.I chose to have some breakfast in the hotel, which was really tasty and there was a good selection of dishes. There are a couple of computers to use in the communal area, as well as a pool table. There is also a small swimming pool and a gym area.I would definitely stay in this hotel again, but only if I did not plan to travel to central Beijing, as it can take a long time. The location is ok if you plan to do a lot of shopping, as there is a big shopping centre just few minutes away from the hotel and there are plenty of eating options around, including restaurants that serve a dog meat!\t\r\n"

# %% [markdown]
# ### Read files into a list
# Now that we've had a sneak peak of our dataset, we can read it into a list so that we can pass this on to the Word2Vec model. Notice in the code below, that I am directly reading the
# compressed file. I'm also doing a mild pre-processing of the reviews using `gensim.utils.simple_preprocess (line)`. This does some basic pre-processing such as tokenization, lowercasing, etc and returns back a list of tokens (words). Documentation of this pre-processing method can be found on the official [Gensim documentation site](https://radimrehurek.com/gensim/utils.html).

# %%
def read_input(input_file):
    """This method reads the input file which is in gzip format"""
    
    logging.info("reading file {0}...this may take a while".format(input_file))
    
    with gzip.open (input_file, 'rb') as f:
        for i, line in enumerate (f): 

            if (i%10000==0):
                logging.info ("read {0} reviews".format (i))
            # do some pre-processing and return a list of words for each review text
            yield gensim.utils.simple_preprocess (line)

# read the tokenized reviews into a list
# each review item becomes a serries of words
# so this becomes a list of lists
documents = list (read_input (data_file))
logging.info ("Done reading data file")   
documents

# %%
documents[:1]

# %% [markdown]
# Test Start

# %%
# import urllib.request
# url = "https://media.githubusercontent.com/media/kavgan/nlp-in-practice/master/word2vec/reviews_data.txt"
# file = urllib.request.urlopen(url)

# for line in file:
# 	decoded_line = line.decode("utf-8",errors='ignore')
# 	print(decoded_line)

# %%
# decoded_line
# Out:
# 'Oct 28 2008 \t?????????????\t\t\r\n'

# %%
# def read_inputTest(input_file):
#     """This method reads the input file which is in gzip format"""
    
#     logging.info("reading file {0}...this may take a while".format(input_file))
    
#     # with gzip.open (input_file, 'rb') as f:
#     for i, line in enumerate (input_file): 

#             if (i%10000==0):
#                 logging.info ("read {0} reviews".format (i))
#             # do some pre-processing and return a list of words for each review text
#             yield gensim.utils.simple_preprocess (line)

# %%
# documentTest = list (read_inputTest (file))
# logging.info ("Done reading data file")   
# documentTest

# %% [markdown]
# Test End

# %% [markdown]
# ## Training the Word2Vec model
#
# Training the model is fairly straightforward. You just instantiate Word2Vec and pass the reviews that we read in the previous step (the `documents`). So, we are essentially passing on a list of lists. Where each list within the main list contains a set of tokens from a user review. Word2Vec uses all these tokens to internally create a vocabulary. And by vocabulary, I mean a set of unique words.
#
# After building the vocabulary, we just need to call `train(...)` to start training the Word2Vec model. Training on the [OpinRank](http://kavita-ganesan.com/entity-ranking-data/) dataset takes about 10 minutes so please be patient while running your code on this dataset.
#
# Behind the scenes we are actually training a simple neural network with a single hidden layer. But, we are actually not going to use the neural network after training. Instead, the goal is to learn the weights of the hidden layer. These weights are essentially the word vectors that we’re trying to learn.

# %%
model = gensim.models.Word2Vec (documents, size=150, window=10, min_count=2, workers=10)
model.train(documents,total_examples=len(documents),epochs=10)
# Out:
# 2021-03-29 09:05:10,412 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2021-03-29 09:05:10,415 : INFO : collecting all words and their counts
# 2021-03-29 09:05:10,418 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-03-29 09:05:10,743 : INFO : PROGRESS: at sentence #10000, processed 1655714 words, keeping 25777 word types
# 2021-03-29 09:05:11,061 : INFO : PROGRESS: at sentence #20000, processed 3317863 words, keeping 35016 word types
# 2021-03-29 09:05:11,461 : INFO : PROGRESS: at sentence #30000, processed 5264072 words, keeping 47518 word types
# 2021-03-29 09:05:11,828 : INFO : PROGRESS: at sentence #40000, processed 7081746 words, keeping 56675 word types
# 2021-03-29 09:05:12,219 : INFO : PROGRESS: at sentence #50000, processed 9089491 words, keeping 63744 word types
# 2021-03-29 09:05:12,610 : INFO : PROGRESS: at sentence #60000, processed 11013726 words, keeping 76786 word types
# 2021-03-29 09:05:12,936 : INFO : PROGRESS: at sentence #70000, processed 12637528 words, keeping 83199 word types
# 2021-03-29 09:05:13,233 : INFO : PROGRESS: at sentence #80000, processed 14099754 words, keeping 88459 word types
# 2021-03-29 09:05:13,552 : INFO : PROGRESS: at sentence #90000, processed 15662152 words, keeping 93357 word types
# 2021-03-29 09:05:13,863 : INFO : PROGRESS: at sentence #100000, processed 17164490 words, keeping 97886 word types
# 2021-03-29 09:05:14,172 : INFO : PROGRESS: at sentence #110000, processed 18652295 words, keeping 102132 word types
# 2021-03-29 09:05:14,477 : INFO : PROGRESS: at sentence #120000, processed 20152532 words, keeping 105923 word types
# 2021-03-29 09:05:14,794 : INFO : PROGRESS: at sentence #130000, processed 21684333 words, keeping 110104 word types
# 2021-03-29 09:05:15,125 : INFO : PROGRESS: at sentence #140000, processed 23330209 words, keeping 114108 word types
# 2021-03-29 09:05:15,433 : INFO : PROGRESS: at sentence #150000, processed 24838757 words, keeping 118174 word types
# 2021-03-29 09:05:15,755 : INFO : PROGRESS: at sentence #160000, processed 26390913 words, keeping 118670 word types
# 2021-03-29 09:05:16,066 : INFO : PROGRESS: at sentence #170000, processed 27913919 words, keeping 123356 word types
# 2021-03-29 09:05:16,394 : INFO : PROGRESS: at sentence #180000, processed 29535615 words, keeping 126748 word types
# 2021-03-29 09:05:16,713 : INFO : PROGRESS: at sentence #190000, processed 31096462 words, keeping 129847 word types
# 2021-03-29 09:05:17,054 : INFO : PROGRESS: at sentence #200000, processed 32805274 words, keeping 133255 word types
# 2021-03-29 09:05:17,381 : INFO : PROGRESS: at sentence #210000, processed 34434201 words, keeping 136364 word types
# 2021-03-29 09:05:17,737 : INFO : PROGRESS: at sentence #220000, processed 36083485 words, keeping 139418 word types
# 2021-03-29 09:05:18,038 : INFO : PROGRESS: at sentence #230000, processed 37571765 words, keeping 142399 word types
# 2021-03-29 09:05:18,365 : INFO : PROGRESS: at sentence #240000, processed 39138193 words, keeping 145232 word types
# 2021-03-29 09:05:18,698 : INFO : PROGRESS: at sentence #250000, processed 40695052 words, keeping 147966 word types
# 2021-03-29 09:05:18,869 : INFO : collected 150059 word types from a corpus of 41519358 raw words and 255404 sentences
# 2021-03-29 09:05:18,871 : INFO : Loading a fresh vocabulary
# 2021-03-29 09:05:19,063 : INFO : effective_min_count=2 retains 70537 unique words (47% of original 150059, drops 79522)
# 2021-03-29 09:05:19,898 : INFO : effective_min_count=2 leaves 41439836 word corpus (99% of original 41519358, drops 79522)
# 2021-03-29 09:05:20,161 : INFO : deleting the raw counts dictionary of 150059 items
# 2021-03-29 09:05:20,170 : INFO : sample=0.001 downsamples 55 most-common words
# 2021-03-29 09:05:20,171 : INFO : downsampling leaves estimated 30349251 word corpus (73.2% of prior 41439836)
# 2021-03-29 09:05:20,463 : INFO : estimated required memory for 70537 words and 150 dimensions: 119912900 bytes
# 2021-03-29 09:05:20,464 : INFO : resetting layer weights
# 2021-03-29 09:05:34,864 : INFO : training model with 10 workers on 70537 vocabulary and 150 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 
words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:25:58,721 : INFO : EPOCH 10 - PROGRESS: at 50.30% examples, 359779 words/s, in_qsize 20, out_qsize 1
# 2021-03-29 09:25:59,723 : INFO : EPOCH 10 - PROGRESS: at 51.44% examples, 359269 words/s, in_qsize 16, out_qsize 3
# 2021-03-29 09:26:00,744 : INFO : EPOCH 10 - PROGRESS: at 52.67% examples, 359591 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:01,787 : INFO : EPOCH 10 - PROGRESS: at 53.88% examples, 359576 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:02,794 : INFO : EPOCH 10 - PROGRESS: at 55.16% examples, 359589 words/s, in_qsize 20, out_qsize 0
# 2021-03-29 09:26:03,835 : INFO : EPOCH 10 - PROGRESS: at 56.54% examples, 359912 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:04,837 : INFO : EPOCH 10 - PROGRESS: at 57.85% examples, 360374 words/s, in_qsize 20, out_qsize 1
# 2021-03-29 09:26:05,838 : INFO : EPOCH 10 - PROGRESS: at 59.12% examples, 360382 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:06,867 : INFO : EPOCH 10 - PROGRESS: at 60.35% examples, 360232 words/s, in_qsize 15, out_qsize 4
# 2021-03-29 09:26:07,942 : INFO : EPOCH 10 - PROGRESS: at 61.72% examples, 360434 words/s, in_qsize 18, out_qsize 1
# 2021-03-29 09:26:09,004 : INFO : EPOCH 10 - PROGRESS: at 63.00% examples, 360177 words/s, in_qsize 17, out_qsize 2
# 2021-03-29 09:26:10,020 : INFO : EPOCH 10 - PROGRESS: at 64.51% examples, 360344 words/s, in_qsize 20, out_qsize 0
# 2021-03-29 09:26:11,073 : INFO : EPOCH 10 - PROGRESS: at 65.69% examples, 360229 words/s, in_qsize 16, out_qsize 3
# 2021-03-29 09:26:12,099 : INFO : EPOCH 10 - PROGRESS: at 66.94% examples, 360398 words/s, in_qsize 16, out_qsize 3
# 2021-03-29 09:26:13,110 : INFO : EPOCH 10 - PROGRESS: at 68.28% examples, 360828 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:14,117 : INFO : EPOCH 10 - PROGRESS: at 69.39% examples, 360384 words/s, in_qsize 18, out_qsize 4
# 2021-03-29 09:26:15,192 : INFO : EPOCH 10 - PROGRESS: at 70.60% examples, 360288 words/s, in_qsize 20, out_qsize 1
# 2021-03-29 09:26:16,229 : INFO : EPOCH 10 - PROGRESS: at 71.83% examples, 360440 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:17,279 : INFO : EPOCH 10 - PROGRESS: at 73.24% examples, 360605 words/s, in_qsize 20, out_qsize 0
# 2021-03-29 09:26:18,333 : INFO : EPOCH 10 - PROGRESS: at 74.56% examples, 360633 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:19,401 : INFO : EPOCH 10 - PROGRESS: at 75.77% examples, 360589 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:20,428 : INFO : EPOCH 10 - PROGRESS: at 76.94% examples, 360646 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:21,436 : INFO : EPOCH 10 - PROGRESS: at 78.03% examples, 360572 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:22,450 : INFO : EPOCH 10 - PROGRESS: at 79.33% examples, 360816 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:23,472 : INFO : EPOCH 10 - PROGRESS: at 80.43% examples, 360493 words/s, in_qsize 19, out_qsize 1
# 2021-03-29 09:26:24,478 : INFO : EPOCH 10 - PROGRESS: at 81.69% examples, 360855 words/s, in_qsize 20, out_qsize 0
# 2021-03-29 09:26:25,486 : INFO : EPOCH 10 - PROGRESS: at 82.86% examples, 360507 words/s, in_qsize 19, out_qsize 3
# 2021-03-29 09:26:26,492 : INFO : EPOCH 10 - PROGRESS: at 84.10% examples, 360769 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:27,507 : INFO : EPOCH 10 - PROGRESS: at 85.19% examples, 360697 words/s, in_qsize 19, out_qsize 2
# 2021-03-29 09:26:28,540 : INFO : EPOCH 10 - PROGRESS: at 86.56% examples, 360886 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:29,576 : INFO : EPOCH 10 - PROGRESS: at 87.93% examples, 360906 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:30,598 : INFO : EPOCH 10 - PROGRESS: at 89.18% examples, 360708 words/s, in_qsize 18, out_qsize 1
# 2021-03-29 09:26:31,730 : INFO : EPOCH 10 - PROGRESS: at 90.57% examples, 360574 words/s, in_qsize 18, out_qsize 1
# 2021-03-29 09:26:32,804 : INFO : EPOCH 10 - PROGRESS: at 91.98% examples, 360790 words/s, in_qsize 18, out_qsize 1
# 2021-03-29 09:26:33,822 : INFO : EPOCH 10 - PROGRESS: at 93.27% examples, 361157 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:34,838 : INFO : EPOCH 10 - PROGRESS: at 94.46% examples, 360725 words/s, in_qsize 20, out_qsize 1
# 2021-03-29 09:26:35,901 : INFO : EPOCH 10 - PROGRESS: at 95.75% examples, 360631 words/s, in_qsize 18, out_qsize 1
# 2021-03-29 09:26:36,914 : INFO : EPOCH 10 - PROGRESS: at 97.05% examples, 360826 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:37,942 : INFO : EPOCH 10 - PROGRESS: at 98.22% examples, 360514 words/s, in_qsize 19, out_qsize 0
# 2021-03-29 09:26:38,988 : INFO : EPOCH 10 - PROGRESS: at 99.56% examples, 360585 words/s, in_qsize 16, out_qsize 1
# 2021-03-29 09:26:39,077 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2021-03-29 09:26:39,088 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2021-03-29 09:26:39,137 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-03-29 09:26:39,163 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-03-29 09:26:39,165 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-03-29 09:26:39,183 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-03-29 09:26:39,196 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-03-29 09:26:39,200 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-03-29 09:26:39,221 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-03-29 09:26:39,226 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-03-29 09:26:39,227 : INFO : EPOCH - 10 : training on 41519358 raw words (30351674 effective words) took 84.1s, 360976 effective words/s
# 2021-03-29 09:26:39,231 : INFO : training on a 415193580 raw words (303502683 effective words) took 841.9s, 360489 effective words/s
# (303502683, 415193580)

# %% [markdown]
# ## Now, let's look at some output
# This first example shows a simple case of looking up words similar to the word `dirty`. All we need to do here is to call the `most_similar` function and provide the word `dirty` as the positive example. This returns the top 10 similar words.

# %%
w1 = "dirty"
model.wv.most_similar (positive=w1)
# Out:
# [('filthy', 0.8667552471160889),
#  ('unclean', 0.7836979627609253),
#  ('dusty', 0.7665246725082397),
#  ('stained', 0.763100266456604),
#  ('smelly', 0.7614609003067017),
#  ('grubby', 0.7605679035186768),
#  ('grimy', 0.7313210368156433),
#  ('dingy', 0.7300260663032532),
#  ('gross', 0.7194393277168274),
#  ('disgusting', 0.7111358642578125)]

# %% [markdown]
# That looks pretty good, right? Let's look at a few more. Let's look at similarity for `polite`, `france` and `shocked`.

# %%
# look up top 6 words similar to 'polite'
w1 = ["polite"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('courteous', 0.9199468493461609),
#  ('friendly', 0.8272396326065063),
#  ('cordial', 0.8093889951705933),
#  ('curteous', 0.7932133674621582),
#  ('professional', 0.7858511805534363),
#  ('attentive', 0.7696643471717834)]

# %%
# look up top 6 words similar to 'france'
w1 = ["france"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('germany', 0.6905314922332764),
#  ('canada', 0.6642270684242249),
#  ('spain', 0.634925365447998),
#  ('england', 0.615372896194458),
#  ('rome', 0.6130086183547974),
#  ('thailand', 0.6075456142425537)]

# %%
# look up top 6 words similar to 'shocked'
w1 = ["shocked"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('horrified', 0.811579704284668),
#  ('amazed', 0.788682222366333),
#  ('astonished', 0.7873637676239014),
#  ('dismayed', 0.7702244520187378),
#  ('stunned', 0.7678093910217285),
#  ('appalled', 0.7554850578308105)]

# %% [markdown]
# That's, nice. You can even specify several positive examples to get things that are related in the provided context and provide negative examples to say what should not be considered as related. In the example below we are asking for all items that *relate to bed* only:

# %%
# get everything related to stuff on the bed
w1 = ["bed",'sheet','pillow']
w2 = ['couch']
model.wv.most_similar (positive=w1,negative=w2,topn=10)
# Out:
# [('mattress', 0.7072802186012268),
#  ('duvet', 0.6995753645896912),
#  ('blanket', 0.6966716647148132),
#  ('quilt', 0.6735424995422363),
#  ('matress', 0.6675796508789062),
#  ('pillowcase', 0.6559816598892212),
#  ('foam', 0.6429517865180969),
#  ('sheets', 0.6373304128646851),
#  ('pillows', 0.6346551775932312),
#  ('pillowcases', 0.5970768332481384)]

# %% [markdown]
# ### Similarity between two words in the vocabulary

# %% [markdown]
# You can even use the Word2Vec model to return the similarity between two words that are present in the vocabulary.

# %%
# similarity between two different words
model.wv.similarity(w1="dirty",w2="smelly")
# Out:
# 0.76146084

# %%
# similarity between two identical words
model.wv.similarity(w1="dirty",w2="dirty")
# Out:
# 1.0

# %%
# similarity between two unrelated words
model.wv.similarity(w1="dirty",w2="clean")
# Out:
# 0.29826522

# %% [markdown]
# Under the hood, the above three snippets computes the cosine similarity between the two specified words using word vectors of each. From the scores, it makes sense that `dirty` is highly similar to `smelly` but `dirty` is dissimilar to `clean`. If you do a similarity between two identical words, the score will be 1.0 as the range of the cosine similarity score will always be between [0.0-1.0]. You can read more about cosine similarity scoring [here](https://en.wikipedia.org/wiki/Cosine_similarity).

# %% [markdown]
# ### Find the odd one out
# You can even use Word2Vec to find odd items given a list of items.

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["cat","dog","france"])
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'france'

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["bed","pillow","duvet","shower"])
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'shower'

# %% [markdown]
# ## Understanding some of the parameters
# To train the model earlier, we had to set some parameters. Now, let's try to understand what some of them mean. For reference, this is the command that we used to train the model.
#
# ```
# model = gensim.models.Word2Vec (documents, size=150, window=10, min_count=2, workers=10)
# ```
#
# ### `size`
# The size of the dense vector to represent each token or word. If you have very limited data, then size should be a much smaller value. If you have lots of data, its good to experiment with various sizes. A value of 100-150 has worked well for me.
#
# ### `window`
# The maximum distance between the target word and its neighboring word. If your neighbor's position is greater than the maximum window width to the left and the right, then, some neighbors are not considered as being related to the target word. In theory, a smaller window should give you terms that are more related. If you have lots of data, then the window size should not matter too much, as long as its a decent sized window.
#
# ### `min_count`
# Minimium frequency count of words. The model would ignore words that do not statisfy the `min_count`. Extremely infrequent words are usually unimportant, so its best to get rid of those. Unless your dataset is really tiny, this does not really affect the model.
#
# ### `workers`
# How many threads to use behind the scenes?

# %% [markdown]
# ## When should you use Word2Vec?
#
# There are many application scenarios for Word2Vec. Imagine if you need to build a sentiment lexicon. Training a Word2Vec model on large amounts of user reviews helps you achieve that. You have a lexicon for not just sentiment, but for most words in the vocabulary.
#
# Beyond, raw unstructured text data, you could also use Word2Vec for more structured data. For example, if you had tags for a million stackoverflow questions and answers, you could find tags that are related to a given tag and recommend the related ones for exploration. You can do this by treating each set of co-occuring tags as a "sentence" and train a Word2Vec model on this data. Granted, you still need a large number of examples to make it work.
